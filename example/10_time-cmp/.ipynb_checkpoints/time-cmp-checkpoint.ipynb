# %% [markdown]
# # time comparison of calcimp by C and Python

# %% [markdown]
# Fisrt make a thin sliced taper data to compare calculation time of calcimp by C language and Python.

# %%
def yy(x):
    return (20*x/1000 + 10)

# %%
yy(0)
# Out:
# 10.0

# %%
yy(1000)
# Out:
# 30.0

# %% [markdown]
# Write data for legacy C version of calcimp.

# %%
f = open('taper.men','w')
f.write('% 10 - 30 taper\n')
for i in range(1000):
    f.write('{0},{1},1,\n'.format(yy(i),yy(i+1)))
f.write('30,0,0,\n')
f.close()

# %% [markdown]
# And for new Python version.

# %%
f = open('taper.xmen','w')
f.write('# 10 - 30 taper\n')
f.write('[,\n')
for i in range(1000):
    f.write('{0},{1},1,\n'.format(yy(i),yy(i+1)))
f.write('30,0,0,\n')
f.write('],\n')
f.close()

# %% [markdown]
# Compare calculation time.

# %%
# !time ~/develop/kanutils-20180129/calcimp taper.men -o taper-c.imp
# Out:
# 1.57user 0.00system 0:01.59elapsed 98%CPU (0avgtext+0avgdata 3412maxresident)k
# 0inputs+104outputs (0major+200minor)pagefaults 0swaps

# %%
# %%time 
# !python /home/yoshinobu/Py_files/calcimpy/calcimpy.py taper.xmen -o taper-python.imp
# Out:
# CPU times: user 240 ms, sys: 44 ms, total: 284 ms
# Wall time: 6.19 s

# %% [markdown]
# Though using numba, python version is ofcourse slower than C version but not bad.

# %%
# !python -m cProfile -s time /home/yoshinobu/Py_files/calcimpy/calcimpy.py taper.xmen
# Out:
#          2697032 function calls (2688231 primitive calls) in 7.427 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    800800    2.979    0.000    5.283    0.000 imped.py:160(calc_impedance)
#    800000    1.733    0.000    1.733    0.000 {built-in method impcore.calc_transmission}
#       801    0.662    0.001    6.243    0.008 imped.py:174(input_impedance)
#    800000    0.571    0.000    0.571    0.000 {built-in method impcore.zo2zi}
#       504    0.179    0.000    0.179    0.000 {built-in method marshal.loads}
#       800    0.178    0.000    0.178    0.000 xmensur.py:160(end_mensur)
#       800    0.120    0.000    0.120    0.000 imped.py:53(radimp)
#     98/66    0.096    0.001    0.234    0.004 {built-in method _imp.create_dynamic}
# 1286/1272    0.065    0.000    0.182    0.000 {built-in method builtins.__build_class__}
#     587/1    0.035    0.000    7.428    7.428 {built-in method builtins.exec}
# ...

# %% [markdown]
# Plot data to check that they are same.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataC = pd.read_csv('taper-c.imp',header = 0)

# %%
dataPy = pd.read_csv('taper-python.imp', header=0)

# %%
dd = pd.DataFrame()

# %% [markdown]
# Merge data for plotting.

# %%
dd['x'] = dataC['freq']
dd['C'] = dataC['mag']
dd['Py'] = dataPy['imp.mag']

# %%
dd.head()
# Out:
#       x          C         Py
# 0   0.0   0.000000   0.000000
# 1   2.5  17.049790  17.049790
# 2   5.0  22.756080  22.756080
# 3   7.5  26.142639  26.142639
# 4  10.0  28.568486  28.568486

# %%
dd.tail()
# Out:
#           x          C         Py
# 796  1990.0  58.207638  58.207638
# 797  1992.5  57.326314  57.326314
# 798  1995.0  56.475939  56.475939
# 799  1997.5  55.651536  55.651536
# 800  2000.0  54.848043  54.848043

# %%
dd.plot( x = 'x', y = ['C','Py'])
# Out:
# /home/yoshinobu/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# Ofcourse output is same.

# %% [markdown]
# More check with compressed mensur data.

# %%
# %%time
# !python /home/yoshinobu/Py_files/calcimpy/calcimpy.py taper-a.xmen
# Out:
# CPU times: user 40 ms, sys: 20 ms, total: 60 ms
# Wall time: 1.44 s

# %%
dataPy2 = pd.read_csv('taper-a.imp', header=0)

# %%
dd['Py2'] = dataPy2['imp.mag']

# %%
dd.plot( x = 'x', y = ['C','Py','Py2'])
# Out:
# /home/yoshinobu/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
dd.head()
# Out:
#       x          C         Py        Py2
# 0   0.0   0.000000   0.000000   0.000000
# 1   2.5  17.049790  17.049790  16.778114
# 2   5.0  22.756080  22.756080  22.556608
# 3   7.5  26.142639  26.142639  25.977318
# 4  10.0  28.568486  28.568486  28.424087
